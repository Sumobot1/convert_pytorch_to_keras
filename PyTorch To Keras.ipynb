# %%
import torch
import numpy as np
import torch.nn as nn


from torch.autograd import Variable
from pytorch2keras.converter import pytorch_to_keras

# %%
# Create Torch tensor with desired input shape
input_np = np.random.uniform(0, 1, (1, 3, 128, 128))
input_var = Variable(torch.FloatTensor(input_np))
# Path to state dict
PATH = '/home/michael/Documents/Github/Michael/vgg_face_descriptor/original_code/VGG_FACE.pth'

# %%
# Paste model here 
model = nn.Sequential( # Sequential,
	nn.Conv2d(3,64,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(64,64,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.MaxPool2d((2, 2),(2, 2),(0, 0),ceil_mode=True),
	nn.Conv2d(64,128,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(128,128,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.MaxPool2d((2, 2),(2, 2),(0, 0),ceil_mode=True),
	nn.Conv2d(128,256,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(256,256,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(256,256,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.MaxPool2d((2, 2),(2, 2),(0, 0),ceil_mode=True),
	nn.Conv2d(256,512,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(512,512,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(512,512,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.MaxPool2d((2, 2),(2, 2),(0, 0),ceil_mode=True),
	nn.Conv2d(512,512,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(512,512,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.Conv2d(512,512,(3, 3),(1, 1),(1, 1)),
	nn.ReLU(),
	nn.MaxPool2d((2, 2),(2, 2),(0, 0),ceil_mode=True),
)

# %%
model.load_state_dict(torch.load(PATH), strict=False)
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=['32.1.weight', '32.1.bias', '35.1.weight', '35.1.bias', '38.1.weight', '38.1.bias'])

# %%
output = model(input_var)

# %%
k_model = pytorch_to_keras(model, input_var, change_ordering=True, verbose=True)
# Out:
# INFO:pytorch2keras:Converter is called.
# DEBUG:pytorch2keras:Input_names:
# DEBUG:pytorch2keras:['input_0']
# DEBUG:pytorch2keras:Output_names:
# DEBUG:pytorch2keras:['output_0']
# INFO:onnx2keras:Converter is called.
# DEBUG:onnx2keras:List input shapes:
# DEBUG:onnx2keras:None
# DEBUG:onnx2keras:List inputs:
# DEBUG:onnx2keras:Input 0 -> input_0.
# DEBUG:onnx2keras:Input 1 -> 0.weight.
# DEBUG:onnx2keras:Input 2 -> 0.bias.
# DEBUG:onnx2keras:Input 3 -> 2.weight.
# DEBUG:onnx2keras:Input 4 -> 2.bias.
# DEBUG:onnx2keras:Input 5 -> 5.weight.
# DEBUG:onnx2keras:Input 6 -> 5.bias.
# DEBUG:onnx2keras:Input 7 -> 7.weight.
# DEBUG:onnx2keras:Input 8 -> 7.bias.
# DEBUG:onnx2keras:Input 9 -> 10.weight.
# DEBUG:onnx2keras:Input 10 -> 10.bias.
# DEBUG:onnx2keras:Input 11 -> 12.weight.
# DEBUG:onnx2keras:Input 12 -> 12.bias.
# DEBUG:onnx2keras:Input 13 -> 14.weight.
# DEBUG:onnx2keras:Input 14 -> 14.bias.
# DEBUG:onnx2keras:Input 15 -> 17.weight.
# DEBUG:onnx2keras:Input 16 -> 17.bias.
# ...

# %%
k_model_json = k_model.to_json()
with open("k_model.json", "w") as json_file:
    json_file.write(k_model_json)
k_model.save_weights("k_model.h5")
